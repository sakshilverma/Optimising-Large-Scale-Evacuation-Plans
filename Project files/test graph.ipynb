# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g=nx.DiGraph()
g.add_node('A', weight=5)
g.add_node('B', weight=10)
g.add_node('O', weight=0)
g.add_edges_from([('A','B')], capacity=2,length=1)
g.add_edges_from([('A','O')], capacity=4,length=3)            
g.add_edges_from([('B','O')], capacity=1,length=2)               
g.add_edges_from([('B','A')], capacity=1,length=1)                                   
print(nx.info(g))
print(g.edges)
pos = nx.spring_layout(g, seed=5)  # positions for all nodes - seed for reproducibility

# nodes
nx.draw_networkx_nodes(g, pos, node_size=700)

# edges
nx.draw_networkx_edges(g, pos, width=6)

# node labels
labeldict={}
labeldict['A']=5
labeldict['B']=2
labeldict['O']=0
nx.draw_networkx_labels(g,pos, labels=labeldict,font_size=20, font_family="sans-serif")
#nx.draw(G, labels=labeldict, with_labels = True)

# edge weight labels
nx.draw_networkx_edge_labels(g, pos, g.edges)
#edge_labels = nx.get_edge_attributes(g, "capacity")
#nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels)

#nx.draw(g)
plt.show()

nx.write_gml(g, "testgraph.gml")
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 3
# Number of edges: 4
# Average in degree:   1.3333
# Average out degree:   1.3333
# [('A', 'B'), ('A', 'O'), ('B', 'O'), ('B', 'A')]
